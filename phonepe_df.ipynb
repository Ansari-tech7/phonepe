# %%
import os
import json
import pandas as pd

# %%
#aggregated transaction data

path1 ="C:/Users/techa/OneDrive/Desktop/phone_pe/pulse/data/aggregated/transaction/country/india/state/"
aggregated_tran_list = os.listdir(path1)

columns1 = {"States":[], "Years":[], "Quarter":[], "Transaction_type":[], "Transaction_count":[],"Transaction_amount":[]}


for state in aggregated_tran_list:
    cur_states =path1 + state+"/"
    agg_years_list = os.listdir(cur_states)

    for year in agg_years_list:
        cur_years = cur_states + year + "/"
        agg_file_list = os.listdir(cur_years)

        for file in agg_file_list:
            cur_files = cur_years + file
            data = open(cur_files, "r")
            A = json.load(data)
            for i in A["data"] ["transactionData"]:
                name = i["name"]
                count = i["paymentInstruments"][0]["count"]
                amount = i["paymentInstruments"][0]["amount"]
                columns1["Transaction_type"].append(name)
                columns1["Transaction_count"].append(count)
                columns1["Transaction_amount"].append(amount)
                columns1["States"].append(state)
                columns1["Years"].append(year)
                columns1["Quarter"].append(int(file.strip(".json")))
agg_transaction = pd.DataFrame(columns1)

agg_transaction["States"] = agg_transaction["States"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
agg_transaction["States"] = agg_transaction["States"].str.replace("-"," ")
agg_transaction["States"] = agg_transaction["States"].str.title()
agg_transaction['States'] = agg_transaction['States'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")

# %%
#aggregated insurance data

path2 = "C:/Users/techa/OneDrive/Desktop/phone_pe/pulse/data/aggregated/insurance/country/india/state/"
agg_insu_list = os.listdir(path2)

columns2 = {"States":[], "Years":[], "Quarter":[], "Insurance_type":[], "Insurance_count":[], "Insurance_amount":[]}

for state in agg_insu_list:
    cur_states = path2 + state + "/"
    agg_years_list = os.listdir(cur_states)

    for year in agg_years_list:
        cur_years = cur_states + year + "/"
        agg_file_list = os.listdir(cur_years)

        for file in agg_file_list:
            cur_files = cur_years + file
            data = open(cur_files, "r")
            B = json.load(data)

            for i in B["data"]["transactionData"]:
                name = i["name"]
                count = i ["paymentInstruments"][0]["count"]
                amount = i ["paymentInstruments"][0]["amount"]
                columns2["Insurance_type"].append(name)
                columns2["Insurance_count"].append(count)
                columns2["Insurance_amount"].append(amount)
                columns2["States"].append(state)
                columns2["Years"].append(year)
                columns2["Quarter"].append(int(file.strip(".json")))

agg_insurance = pd.DataFrame(columns2)

agg_insurance["States"] = agg_insurance["States"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
agg_insurance["States"] = agg_insurance["States"].str.replace("-"," ")
agg_insurance["States"] = agg_insurance["States"].str.title()
agg_insurance['States'] = agg_insurance['States'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")

# %%
#aggregated user data

path3 = "C:/Users/techa/OneDrive/Desktop/phone_pe/pulse/data/aggregated/user/country/india/state/"
agg_user_list = os.listdir(path3)

columns3 = {"States":[], "Years":[], "Quarter":[], "Registered_Users":[], "App_open":[]}

for state in agg_user_list:
    cur_state = path3 + state + "/"
    agg_years_list = os.listdir(cur_state)

    for year in agg_years_list:
        cur_year = cur_state + year + "/"
        agg_file_list = os.listdir(cur_year)

        for file in agg_file_list:
            cur_files = cur_year + file
            data = open(cur_files, "r")
            C = json.load(data)
            
            agg = C["data"]["aggregated"]
            registered_users = agg["registeredUsers"]
            app_open = agg["appOpens"]
            columns3["Registered_Users"].append(registered_users)
            columns3["App_open"].append(app_open)  
            columns3["States"].append(state)
            columns3["Years"].append(year) 
            columns3["Quarter"].append(int(file.strip(".json")))
agg_user = pd.DataFrame(columns3)

agg_user["States"] = agg_user["States"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
agg_user["States"] = agg_user["States"].str.replace("-"," ")
agg_user["States"] = agg_user["States"].str.title()
agg_user['States'] = agg_user['States'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")

# %%
u_path3 = "C:/Users/techa/OneDrive/Desktop/phone_pe/pulse/data/aggregated/user/country/india/state/"
agg_user_device = os.listdir(path3)

columns4 = {"States":[], "Years":[], "Quarter":[], "Brand":[], "Count":[], "Percentage":[]}

for state in agg_user_device:
    cur_state = path3 + state + "/"
    agg_years_list = os.listdir(cur_state)

    for year in agg_years_list:
        cur_year = cur_state + year + "/"
        agg_file_list = os.listdir(cur_year)

        for file in agg_file_list:
            cur_files = cur_year + file
            data = open(cur_files, "r")
            D = json.load(data)

            
            try:

                for i in D["data"]["usersByDevice"]:
                    brand = i["brand"]
                    count = i["count"]
                    percentage = i["percentage"]
                    columns4["Brand"].append(brand)
                    columns4["Count"].append(count)
                    columns4["Percentage"].append(percentage)
                    columns4["States"].append(state)
                    columns4["Years"].append(year)
                    columns4["Quarter"].append(int(file.strip(".json")))
            
            except:
                pass
agg_user_device = pd.DataFrame(columns4)

agg_user_device["States"] = agg_user_device["States"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
agg_user_device["States"] = agg_user_device["States"].str.replace("-"," ")
agg_user_device["States"] = agg_user_device["States"].str.title()
agg_user_device['States'] = agg_user_device['States'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")

# %%
#map insurance data

path1 = "C:/Users/techa/OneDrive/Desktop/phone_pe/pulse/data/map/insurance/hover/country/india/state/"
map_insur_list = os.listdir(path1)

columns8 = {
    "State": [],
    "Year": [],
    "Quarter": [],
    "District": [],
    "Transaction_Count": [],
    "Transaction_Amount": []
}

for state in map_insur_list:
    cur_states = path1 + state + "/"
    agg_year_list = os.listdir(cur_states)
    
    for year in agg_year_list:
        cur_years = cur_states + year + "/"
        agg_file_list = os.listdir(cur_years)

        for file in agg_file_list:
            cur_files = cur_years + file

            # ✅ Safe open
            with open(cur_files, "r") as data:
                D = json.load(data)

            hover = D["data"].get("hoverDataList")

            # ✅ Handle NULL
            if hover is not None:
                for i in hover:
                    district = i["name"]

                    for m in i["metric"]:
                        columns8["District"].append(district)
                        columns8["Transaction_Count"].append(m["count"])
                        columns8["Transaction_Amount"].append(m["amount"])
                        columns8["State"].append(state)
                        columns8["Year"].append(int(year))
                        columns8["Quarter"].append(int(file.strip(".json")))

map_insurance = pd.DataFrame(columns8)

# ✅ Clean State Names
map_insurance["State"] = map_insurance["State"].str.replace("-", " ").str.title()

# ✅ Clean District Names
map_insurance["District"] = map_insurance["District"].str.replace("-", " ").str.title()

print("✅ Done")
# Out:
# ✅ Done

# %%
#map transaction data

path2 = "C:/Users/techa/OneDrive/Desktop/phone_pe/pulse/data/map/transaction/hover/country/india/state/"
map_tran_list = os.listdir(path2)

columns6 = {"States":[], "Years":[], "Quarter":[], "Districts":[], "Transaction_count":[], "Transaction_amount":[]}

for state in map_tran_list:
    cur_states = path2 + state + "/"
    map_years_list = os.listdir(cur_states)

    for year in map_years_list:
        cur_years = cur_states + year + "/"
        map_file_list = os.listdir(cur_years)

        for file in map_file_list:
            cur_files = cur_years + file
            data = open(cur_files, "r")
            F = json.load(data)
            
            for i in F["data"]["hoverDataList"]:
                district = i["name"]
                count = i["metric"][0]["count"]
                amount = i["metric"][0]["amount"]
                columns6["Districts"].append(district)
                columns6["Transaction_count"].append(count)
                columns6["Transaction_amount"].append(amount)
                columns6["States"].append(state)
                columns6["Years"].append(year)
                columns6["Quarter"].append(int(file.strip(".json")))
map_transaction_hover = pd.DataFrame(columns6)


# ✅ Clean State Names
map_transaction_hover["States"] = map_transaction_hover["States"].str.replace("-", " ").str.title()

# ✅ Clean District Names
map_transaction_hover["Districts"] = map_transaction_hover["Districts"].str.replace("-", " ").str.title()

print("✅ Done")
# Out:
# ✅ Done

# %%
#map user data


path3 = "C:/Users/techa/OneDrive/Desktop/phone_pe/pulse/data/map/user/hover/country/india/state/"
map_user_list = os.listdir(path3)

columns7 = {
    "State": [],
    "Year": [],
    "Quarter": [],
    "District": [],
    "Registered_Users": [],
    "App_Opens": []
}

for state in map_user_list:
    cur_states = path3 + state + "/"
    map_years_list = os.listdir(cur_states)

    for year in map_years_list:
        cur_years = cur_states + year + "/"
        map_file_list = os.listdir(cur_years)

        for file in map_file_list:
            cur_files = cur_years + file

            with open(cur_files, "r") as data:
                G = json.load(data)

            hover = G["data"].get("hoverData")

            # ✅ Correct structure handling
            if hover is not None:
                for district, values in hover.items():
                    columns7["District"].append(district)
                    columns7["Registered_Users"].append(values["registeredUsers"])
                    columns7["App_Opens"].append(values["appOpens"])
                    columns7["State"].append(state)
                    columns7["Year"].append(int(year))
                    columns7["Quarter"].append(int(file.strip(".json")))

# Create DataFrame
map_user_hover = pd.DataFrame(columns7)

# Clean names
map_user_hover["State"] = map_user_hover["State"].str.replace("-", " ").str.title()
map_user_hover["District"] = map_user_hover["District"].str.replace("-", " ").str.title()

print("✅ Fixed Successfully")
# Out:
# ✅ Fixed Successfully

# %%
#top insurance data

# Path
path_insurance = "C:/Users/techa/OneDrive/Desktop/phone_pe/pulse/data/top/insurance/country/india/state/"
top_insur_list = os.listdir(path_insurance)

# Columns
columns_insurance = {
    "State": [],
    "Year": [],
    "Quarter": [],
    "Pincode": [],
    "Transaction_Count": [],
    "Transaction_Amount": []
}

# Loop
for state in top_insur_list:
    cur_state = path_insurance + state + "/"
    year_list = os.listdir(cur_state)

    for year in year_list:
        cur_year = cur_state + year + "/"
        file_list = os.listdir(cur_year)

        for file in file_list:
            cur_file = cur_year + file

            with open(cur_file, "r") as data:
                D = json.load(data)

            pincodes = D["data"].get("pincodes")

            if pincodes is not None:
                for i in pincodes:
                    columns_insurance["Pincode"].append(i["entityName"])
                    columns_insurance["Transaction_Count"].append(i["metric"]["count"])
                    columns_insurance["Transaction_Amount"].append(i["metric"]["amount"])
                    columns_insurance["State"].append(state)
                    columns_insurance["Year"].append(int(year))
                    columns_insurance["Quarter"].append(int(file.strip(".json")))

# DataFrame
top_insurance = pd.DataFrame(columns_insurance)

# Clean Data
top_insurance["State"] = top_insurance["State"].str.replace("-", " ").str.title()

print("✅ Top Insurance Ready")
# Out:
# ✅ Top Insurance Ready

# %%
# top transaction data

# Path
path_transaction = "C:/Users/techa/OneDrive/Desktop/phone_pe/pulse/data/top/transaction/country/india/state/"
top_tran_list = os.listdir(path_transaction)

# Columns
columns_transaction = {
    "State": [],
    "Year": [],
    "Quarter": [],
    "Pincode": [],
    "Transaction_Count": [],
    "Transaction_Amount": []
}

# Loop
for state in top_tran_list:
    cur_state = path_transaction + state + "/"
    year_list = os.listdir(cur_state)

    for year in year_list:
        cur_year = cur_state + year + "/"
        file_list = os.listdir(cur_year)

        for file in file_list:
            cur_file = cur_year + file

            with open(cur_file, "r") as data:
                H = json.load(data)

            pincodes = H["data"].get("pincodes")

            if pincodes is not None:
                for i in pincodes:
                    columns_transaction["Pincode"].append(i["entityName"])
                    columns_transaction["Transaction_Count"].append(i["metric"]["count"])
                    columns_transaction["Transaction_Amount"].append(i["metric"]["amount"])
                    columns_transaction["State"].append(state)
                    columns_transaction["Year"].append(int(year))
                    columns_transaction["Quarter"].append(int(file.strip(".json")))

# DataFrame
top_transaction = pd.DataFrame(columns_transaction)

# Clean Data
top_transaction["State"] = top_transaction["State"].str.replace("-", " ").str.title()

print("✅ Top Transaction Ready")
# Out:
# ✅ Top Transaction Ready

# %%
#top user data

# Path
path_user = "C:/Users/techa/OneDrive/Desktop/phone_pe/pulse/data/top/user/country/india/state/"
top_user_list = os.listdir(path_user)

# Columns
columns_user = {
    "State": [],
    "Year": [],
    "Quarter": [],
    "Pincode": [],
    "Registered_Users": []
}

# Loop
for state in top_user_list:
    cur_state = path_user + state + "/"
    year_list = os.listdir(cur_state)

    for year in year_list:
        cur_year = cur_state + year + "/"
        file_list = os.listdir(cur_year)

        for file in file_list:
            cur_file = cur_year + file

            with open(cur_file, "r") as data:
                I = json.load(data)

            pincodes = I["data"].get("pincodes")

            if pincodes is not None:
                for i in pincodes:
                    columns_user["Pincode"].append(i["name"])
                    columns_user["Registered_Users"].append(i["registeredUsers"])
                    columns_user["State"].append(state)
                    columns_user["Year"].append(int(year))
                    columns_user["Quarter"].append(int(file.strip(".json")))

# DataFrame
top_user = pd.DataFrame(columns_user)

# Clean Data
top_user["State"] = top_user["State"].str.replace("-", " ").str.title()

print("✅ Top User Ready")
# Out:
# ✅ Top User Ready

# %% [markdown]
# postgresql connection

# %%
import psycopg2
from sqlalchemy import create_engine

# Database credentials
db_user = 'postgres'
db_password = 'ansaris'
db_host = '127.0.0.1'
db_port = '5432'   # or 5432
db_name = 'phonepe'

# Create connection
engine = create_engine(
    f'postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'
)

print("✅ Connected Successfully")
# Out:
# ✅ Connected Successfully

# %% [markdown]
# 📊 AGGREGATED TABLES
